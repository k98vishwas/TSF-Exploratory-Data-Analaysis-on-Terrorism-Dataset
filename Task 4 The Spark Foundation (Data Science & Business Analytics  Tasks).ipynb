# %% [markdown]
# ## Name: Vishwas Sunil Kshirsagar
#
#
# ## Task 4: Exploratory Data Analysis - Terrorism

# %% [markdown]
# ### Problem Statement: Perform 'Exploratory Data Analysis' on dataset 'Global Terrorism'

# %%
# Importing all the neccessary libraries

import pandas as pd  # to analyze data
import numpy as np  # to perform a wide variety of mathematical operations on arrays
import seaborn as sns # to visualize random distributions.
import matplotlib.pyplot as plt # to perform data visualization and graphical plotting
# %matplotlib inline

# in case of any warnings
import warnings as wg

# %%
# let's load and read the dataset.
global_t = pd.read_csv("C:/The Spark Foundation/globalterrorism.csv",encoding="ISO-8859-1")
# Out:
# C:\Users\vishw\AppData\Local\Temp\ipykernel_9144\539061345.py:2: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   global_t = pd.read_csv("C:/The Spark Foundation/globalterrorism.csv",encoding="ISO-8859-1")

# %%
# print the first 5 record

global_t.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
# Print the last 5 records

global_t.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
# print the shape of the dataset

global_t.shape   # dataset has total 181691 rows and 135 columns
# Out:
# (181691, 135)

# %%
# print the information of the datset

global_t.info
# Out:
# <bound method DataFrame.info of              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
# ...

# %%
# print the total columns names in the dataset

global_t.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %%
# print the five point summary of the dataset(mean,median, mode, max, min)

global_t.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
# let's print the correlation between 2 variables.

global_t.corr()
# Out:
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.999996  0.002706  0.018336  0.091761 -0.135039
# iyear      0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth     0.002706  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday       0.018336  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended   0.091761  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# ...             ...       ...       ...       ...       ...       ...
# nreleased -0.181612 -0.181556 -0.011535  0.001765 -0.192155 -0.044331
# INT_LOG   -0.143600 -0.143601 -0.002302 -0.001540  0.071768  0.069904
# INT_IDEO  -0.133252 -0.133253 -0.002034 -0.001621  0.075147  0.067564
# INT_MISC  -0.077852 -0.077847 -0.002554 -0.002027  0.027335  0.207281
# INT_ANY   -0.175605 -0.175596 -0.006336 -0.001199  0.080767  0.153118
#
#              region  latitude  longitude  specificity  ...  ransomamt  \
# ...

# %%
# print the null values if there are any

global_t.isnull().sum()   # there is total 13853997 null values/records
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
# let's check whether we have duplicate values in the dataset

global_t. duplicated().sum()    # there are no duplicats
# Out:
# 0

# %%
# print number of unique value in the dataset

for i in global_t.columns:
    print(i,len(global_t[i].unique()))
# Out:
# eventid 181691
# iyear 47
# imonth 13
# iday 32
# approxdate 2245
# extended 2
# resolution 1860
# country 205
# country_txt 205
# region 12
# region_txt 12
# provstate 2856
# city 36675
# latitude 48323
# longitude 48040
# specificity 6
# vicinity 3
# location 44110
# summary 112493
# crit1 2
# crit2 2
# crit3 2
# doubtterr 4
# alternative 6
# alternative_txt 6
# multiple 3
# success 2
# suicide 2
# attacktype1 9
# attacktype1_txt 9
# attacktype2 10
# attacktype2_txt 10
# attacktype3 9
# attacktype3_txt 9
# targtype1 22
# targtype1_txt 22
# targsubtype1 113
# targsubtype1_txt 113
# corp1 33239
# target1 86007
# natlty1 216
# natlty1_txt 216
# targtype2 23
# targtype2_txt 23
# targsubtype2 108
# targsubtype2_txt 108
# corp2 2692
# target2 5044
# natlty2 159
# natlty2_txt 159
# targtype3 21
# targtype3_txt 21
# targsubtype3 93
# targsubtype3_txt 93
# corp3 423
# target3 721
# natlty3 111
# natlty3_txt 111
# gname 3537
# gsubname 1184
# gname2 434
# gsubname2 61
# gname3 117
# ...

# %%
# let's represent the correlation in the form of graph

global_t.hist(figsize = (50,55))

plt.show()

# %%
# let's print region terrorist activity in each yeaer using count plot

sns.set(rc={'figure.figsize': (25,40)})
sns.countplot(x=global_t["iyear"], hue=global_t["region_txt"])
plt.title("Region-wise Terrorist Activity in Each Year")
# Out:
# Text(0.5, 1.0, 'Region-wise Terrorist Activity in Each Year')

# %%
# to understand and explore in deep lets try to visualize it with cross tab

pd.crosstab(global_t['iyear'], global_t['region_txt']).plot(kind="line",figsize=(15,20))
plt.title("Region-wise Terrorist Activity in Each Year")
plt.ylabel("Number of Attacks")
plt.xlabel("Years")
plt.show()

# %% [markdown]
# ### From 2001 global terrorism has increased so badly. major impact took place in Middle east and North Africa region.

# %%
# let's find out most affected region

global_t["region_txt"].value_counts()  # Ass per the data Middle East & North Africa are most affected
# Out:
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: region_txt, dtype: int64

# %%
# let's print most affected countires 

global_t["country_txt"].value_counts()     # country wise Iraq, pakistan and Afghanistan are most affected countires.
# Out:
# Iraq                   24636
# Pakistan               14368
# Afghanistan            12731
# India                  11960
# Colombia                8306
#                        ...
# International              1
# Wallis and Futuna          1
# South Vietnam              1
# Andorra                    1
# Antigua and Barbuda        1
# Name: country_txt, Length: 205, dtype: int64

# %%
# let's print top 15 countires affected by Terrorism

plt.figure(figsize=(15,6))
sns.barplot(global_t["country_txt"].value_counts()[:15].index, global_t["country_txt"].value_counts()[:15].values)
plt.title("Top 15 Countries Affected by Attacks", fontsize=15)
plt.ylabel("Counts", fontsize = 15)
plt.xlabel("Countries", fontsize = 15)
plt.show()


print("Most Affected Countries are Ireq and Pakistan.")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Most Affected Countries are Ireq and Pakistan.

# %%
# Let's also find out most affected states.

plt.figure(figsize = (15,6))
sns.barplot(global_t["city"].value_counts()[:5].index, global_t["city"].value_counts()[:5].values)
plt.title("Top 5 Cities Affected by Attacks", fontsize = 15)
plt.ylabel("Counts", fontsize = 15)
plt.xlabel("City", fontsize = 15)

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Most Affected City Name is not mentioned and the second most affected is BAGHDAD.

# %%
# let's find out weapon type used for terrorism attacks

sns.set(rc = {"figure.figsize": (30,7)})
sns.countplot(x= global_t["region_txt"], hue = global_t["weaptype1_txt"])
plt.title("Weapon Type used in Per Region")
plt.xlabel("Region", fontsize = 15)
# Out:
# Text(0.5, 0, 'Region')

# %% [markdown]
# ### Explosives, Chemicals and Firearms are widely used as a weapon type to destroy harmony.

# %%
# let's visualize what are the attack types has been used in Middle East and North Africa

sns.set(rc = {"figure.figsize": (30,7)})
sns.countplot(x= global_t["region_txt"], hue = global_t["attacktype1_txt"])
plt.title("Attack Type used in Per Region")
plt.xlabel("Region", fontsize = 15)
# Out:
# Text(0.5, 0, 'Region')

# %% [markdown]
# ### Bombing and Explosion is highly used in Middle Ease and North Africa Region.

# %%
# let's find out property types where attacks took place in huge numbers

sns.set(rc = {"figure.figsize": (30,7)})
sns.countplot(x= global_t["region_txt"], hue = global_t["targtype1_txt"])
plt.title("Most Affected Property Type")
plt.xlabel("Region", fontsize = 15)
# Out:
# Text(0.5, 0, 'Region')

# %% [markdown]
# ### Private property has been targated mostly by the terrorist. and colateral damage as per the graph is devastating.

# %%
# let's understand total number of death and injuries in overall.

global_t.plot(kind="scatter", x = "nkill", y = "nwound", color = "red", figsize = (10,10),fontsize = 15)
plt.xlabel("Kill")
plt.ylabel("Wound")
plt.title("Killed - Wounded Scatter Plot")
plt.show()

# %% [markdown]
# ### With the big explosion death and number of injuries are less but in case of small attacks number of deaths and Injuries are more.

# %% [markdown]
# # Pakistan Analysis

# %%
# let's analyze the data of Pakistan 

pakistan_c = global_t[global_t["country_txt"] == "Pakistan"]["city"]
pakistan_c.value_counts()
# Out:
# Karachi          2651
# Peshawar          819
# Quetta            803
# Lahore            233
# Jamrud            160
#                  ...
# Thakata Baig        1
# Bab-i-Dosti         1
# Jam                 1
# Killi Ibrahim       1
# Jalal               1
# Name: city, Length: 2283, dtype: int64

# %% [markdown]
# ### karachi and peshawar are the most affected cities of Pakistan.

# %%
plt.figure(figsize = (15,6))
sns.barplot(global_t["city"].value_counts()[:5].index, global_t["city"].value_counts()[:5].values)
plt.title("Top 5 Terrorism affected cities of Pakistan", fontsize = 15)
plt.ylabel("City", fontsize = 15)
plt.xlabel("Attacks", fontsize = 15)

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### As per the graph Unknows, Baghdad and karachi are the most affected cities.

# %%
# let's find out top 5 cities with attacks details

attack_cities = global_t[global_t["country_txt"] == "Pakistan"][["city", "iyear", "attacktype1_txt", "gname"]]

attack_cities[:5]
# Out:
#             city  iyear    attacktype1_txt                 gname
# 585      Karachi   1970      Assassination               Unknown
# 2217     Karachi   1974  Bombing/Explosion     Muslim Guerrillas
# 2705    Peshawar   1974  Bombing/Explosion               Unknown
# 2744  Rawalpindi   1975  Bombing/Explosion               Unknown
# 2795    Peshawar   1975      Assassination  National Awami Party

# %% [markdown]
# ### Assasination, Bombing/Explosion are the main attack types in pakistan's terrorism.

# %%
# Let's find out top 10 terrorism groups exist in the world

global_t["gname"].value_counts()[:10]
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Name: gname, dtype: int64

# %%
# Visualizing top terrorist groups exists in Pakistan

terrorist_pak = global_t[global_t["country_txt"]== "Pakistan"]["gname"]

terrorist_pak[:10]
# Out:
# 585                          Unknown
# 2217               Muslim Guerrillas
# 2705                         Unknown
# 2744                         Unknown
# 2795            National Awami Party
# 4180                         Unknown
# 4181                    Palestinians
# 4214    Abu Nidal Organization (ANO)
# 6583                    Palestinians
# 6592    Abu Nidal Organization (ANO)
# Name: gname, dtype: object

# %%
# Let's find out terrorist attacks happened in Pakistan overall.

pak_attack = global_t[global_t["country_txt"] == "Pakistan"]["iyear"]

pak_attack.value_counts()
# Out:
# 2013    2215
# 2014    2151
# 2012    1654
# 2015    1243
# 2011    1012
# 2016     864
# 2017     719
# 2010     713
# 2009     667
# 1995     666
# 2008     568
# 2007     260
# 1997     206
# 1996     180
# 2006     164
# 1994     154
# 1991     150
# 1990      87
# 1992      85
# 2005      77
# 2004      67
# 1987      60
# 2001      53
# 2000      49
# 2002      46
# 1989      45
# 1988      44
# 1999      39
# 1998      37
# 2003      29
# 1986      24
# 1983       9
# 1979       7
# 1982       4
# 1981       4
# 1984       3
# 1976       3
# 1974       2
# 1985       2
# 1978       2
# 1975       2
# 1980       1
# 1970       1
# Name: iyear, dtype: int64

# %% [markdown]
# ### In the year of 2013 '2215' attack has happened in Pakistan.

# %%
# let's find out top terrorist attack type took place in Pakistan

pak_ter_attack = global_t[global_t["country_txt"] == "Pakistan"]["attacktype1_txt"]

pak_ter_attack.value_counts()
# Out:
# Bombing/Explosion                      7613
# Armed Assault                          3859
# Assassination                          1406
# Hostage Taking (Kidnapping)             823
# Facility/Infrastructure Attack          300
# Unknown                                 236
# Unarmed Assault                          77
# Hostage Taking (Barricade Incident)      35
# Hijacking                                19
# Name: attacktype1_txt, dtype: int64

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### 1.Most Attacks took place in Iraq.
#
# ### 2. Most Attacks in City: Baghdad.
#
# ### 3. Most Attack Region: Middle East and North Africa
#
# ### 4. Least Attack Region: Australia and Oceania
#
# ### 5. Most Attacks Year: 2014
#
# ### 6. Most Attacks Month: 5
#
# ### 7. Most Attacks by Group: Taliban
#
# ### 8. Most Attacks Type: Bombing/Explosion
#
# ### 9. Most Target Property Type: Private Citizen Property
#
# ### 10. Most Target Continent: Asia
#
# ### 11. Least Attacks Type: Hijacking
#
# ### 12. least Attacks Year: 1971

# %% [markdown]
# # Pakistan Country Analysis:

# %% [markdown]
# ### 1. Most Affected City: Karachi
#
# ### 2. Most Active Terrorist Group: Abu Nidal Organization (ANO)
#
# ### 3. Most Affected Year: 2013
#
# ### 4. Least Affected Year: 1970
#
# ### 5. Most Attack Type: Bombing/Explosion
#
# ### 6. Least Attack Type: Hijacking

# %% [markdown]
# In majority of terrorist attack injuries and deaths have been less as compare to smaller explosion, attacks. In order to save terrorist attacks we have to tighten the securities of every country and mostly have to train more deplomat to avoid these unforeseen explosion.
